# %%
from utils.tiny_cnn import fast_train_model, TinyCNN

fast_train_model(TinyCNN(), "TinyCNN")
# Out:
# 🚀 开始快速训练 TinyCNN...
# Epoch 1/30: Loss = 4.117, Train Acc = 6.71%, Test Acc = 13.45%
# Epoch 6/30: Loss = 3.435, Train Acc = 16.75%, Test Acc = 25.80%
# Epoch 11/30: Loss = 3.193, Train Acc = 21.31%, Test Acc = 31.40%
# Epoch 16/30: Loss = 3.007, Train Acc = 25.10%, Test Acc = 36.30%
# Epoch 21/30: Loss = 2.897, Train Acc = 27.05%, Test Acc = 38.50%
# Epoch 26/30: Loss = 2.819, Train Acc = 28.56%, Test Acc = 39.45%
# Epoch 30/30: Loss = 2.811, Train Acc = 28.97%, Test Acc = 39.85%
# 🎉 TinyCNN 训练完成! 最佳准确率: 39.85%
# (TinyCNN(
#    (features): Sequential(
#      (0): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#      (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#      (2): ReLU(inplace=True)
#      (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#      (4): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#      (5): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#      (6): ReLU(inplace=True)
#      (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#      (8): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#      (9): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#      (10): ReLU(inplace=True)
#      (11): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#    )
#    (classifier): Sequential(
#      (0): Dropout(p=0.5, inplace=False)
#      (1): Linear(in_features=1024, out_features=256, bias=True)
#      (2): ReLU(inplace=True)
#      (3): Dropout(p=0.5, inplace=False)
#      (4): Linear(in_features=256, out_features=100, bias=True)
#    )
#  ),
#  39.85)

# %%
from utils.res_net import ResNet20
import torch

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
teacher_model = ResNet20(num_classes=100).to(device)
teacher_model.load_state_dict(
    torch.load("../model_weights/student_vanilla_resnet20_best.pth")
)

fast_train_model(TinyCNN(), "TinyCNN", use_distillation=True, teacher_model=teacher_model)
# Out:
# 🚀 开始快速训练 TinyCNN...
# Epoch 1/30: Loss = 7.742, Train Acc = 7.25%, Test Acc = 13.80%
# Epoch 6/30: Loss = 6.764, Train Acc = 18.49%, Test Acc = 27.95%
# Epoch 11/30: Loss = 6.448, Train Acc = 22.65%, Test Acc = 34.85%
# Epoch 16/30: Loss = 6.227, Train Acc = 25.72%, Test Acc = 38.20%
# Epoch 21/30: Loss = 6.042, Train Acc = 27.55%, Test Acc = 39.85%
# Epoch 26/30: Loss = 5.979, Train Acc = 28.71%, Test Acc = 40.10%
# Epoch 30/30: Loss = 5.957, Train Acc = 29.17%, Test Acc = 40.70%
# 🎉 TinyCNN 训练完成! 最佳准确率: 40.70%
# (TinyCNN(
#    (features): Sequential(
#      (0): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#      (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#      (2): ReLU(inplace=True)
#      (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#      (4): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#      (5): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#      (6): ReLU(inplace=True)
#      (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#      (8): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#      (9): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#      (10): ReLU(inplace=True)
#      (11): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#    )
#    (classifier): Sequential(
#      (0): Dropout(p=0.5, inplace=False)
#      (1): Linear(in_features=1024, out_features=256, bias=True)
#      (2): ReLU(inplace=True)
#      (3): Dropout(p=0.5, inplace=False)
#      (4): Linear(in_features=256, out_features=100, bias=True)
#    )
#  ),
#  40.7)

# %%
from utils.res_net import ResNet20
from utils.tiny_cnn import fast_train_model, TinyCNN
import torch

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
teacher_model = ResNet20(num_classes=100).to(device)
teacher_model.load_state_dict(
    torch.load("../model_weights/student_vanilla_resnet20_best.pth")
)

# 调参
for alpha in [0.3, 0.5, 0.7, 0.9]:
    for temperature in [2, 4, 8]:
        fast_train_model(TinyCNN(), "TinyCNN", use_distillation=True, teacher_model=teacher_model, alpha=alpha, temperature=temperature)
# Out:
# 🚀 开始快速训练 TinyCNN...
# Epoch 1/30: Loss = 6.591, Train Acc = 6.94%, Test Acc = 12.85%
# Epoch 6/30: Loss = 5.489, Train Acc = 18.21%, Test Acc = 26.85%
# Epoch 11/30: Loss = 5.128, Train Acc = 22.59%, Test Acc = 34.05%
# Epoch 16/30: Loss = 4.860, Train Acc = 26.10%, Test Acc = 38.05%
# Epoch 21/30: Loss = 4.696, Train Acc = 28.39%, Test Acc = 40.15%
# Epoch 26/30: Loss = 4.587, Train Acc = 29.98%, Test Acc = 41.25%
# Epoch 30/30: Loss = 4.579, Train Acc = 30.29%, Test Acc = 41.80%
# 🎉 TinyCNN 训练完成! 最佳准确率: 41.80%
# 🚀 开始快速训练 TinyCNN...
# Epoch 1/30: Loss = 5.668, Train Acc = 6.73%, Test Acc = 13.65%
# Epoch 6/30: Loss = 4.874, Train Acc = 18.31%, Test Acc = 28.45%
# Epoch 11/30: Loss = 4.592, Train Acc = 22.91%, Test Acc = 34.15%
# Epoch 16/30: Loss = 4.408, Train Acc = 25.65%, Test Acc = 38.45%
# Epoch 21/30: Loss = 4.279, Train Acc = 28.40%, Test Acc = 40.55%
